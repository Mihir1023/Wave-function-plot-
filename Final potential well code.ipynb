# %%
import math
from matplotlib import pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = [5, 5]
L=3.14
n=int(input("enter size of orbital"))
def psi(x):
    return (np.sqrt(L/2)*np.sin((n*3.14)*x/L))
x=np.linspace(0, 3.14, 100)    
y=psi(x)
plt.xlabel("x")
plt.ylabel("Ψ(x)")
plt.plot(x, y)
plt.show()
ul= psi(L/2)
ll= psi(-L/2)
print("The values of upper most value of function is",ul,"and the lower must values is",ll)
# Out:
# enter size of orbital 4
# The values of upper most value of function is -0.003991171707154168 and the lower must values is 0.003991171707154168
